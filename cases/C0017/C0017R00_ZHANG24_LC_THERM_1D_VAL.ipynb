# %% [markdown]
# This one is an update to a previous script "BTMS T Solver.ipynb", which aims to locate the temperature distribution for liquid cooling BTMS. Also, this one integrates several cells in notebook 'Liquid cooling BTMS 1D modelling.ipynb', which was developed based a previous script shared by Liu Mingxin.

# %%
# 读取本地 CFD .out 文件，并与液冷结果、BLC max/min 画在同一张图上
import os
from pathlib import Path
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

PROJECT_ROOT = os.path.abspath("../..")
CASE_ID = "C0017"
CASE_NAME = "C0017R00_ZHANG24_LC_THERM_1D_VAL"


# 本地 .out 数据文件夹。
# 数据文件就在程序/notebook 所在文件夹时，不需要改路径；直接放在同一目录即可。
# 在 Jupyter 中这里读取当前 notebook 的运行目录。
CFD_DATA_DIR = os.path.join(PROJECT_ROOT, "data","HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max")


def read_out_temperature(filename, series_name, data_dir=CFD_DATA_DIR):
    """
    读取本地文件夹中的 .out 文件。
    文件应至少包含两列数值：时间/步数 和 温度值。
    支持空格、Tab、逗号分隔；自动跳过表头和注释行。

    对 Fluent report .out 文件，常见格式为：
        Time Step, report-def, flow-time
    本函数默认取第 1 个数值为横坐标、第 2 个数值为温度。
    """
    path = Path(data_dir) / filename
    if not path.exists():
        raise FileNotFoundError(
            f"未找到 {path}。请确认 {filename} 和这个 notebook/program 放在同一个文件夹，"
            "或手动修改 CFD_DATA_DIR。"
        )

    rows = []
    with path.open("r", encoding="utf-8", errors="ignore") as f:
        for line in f:
            line = line.strip()
            if not line or line.startswith(("#", "//")):
                continue

            # 提取每一行中的数值，兼容 scientific notation。
            nums = re.findall(r"[-+]?(?:\d+\.\d*|\.\d+|\d+)(?:[eE][-+]?\d+)?", line)
            if len(nums) >= 2:
                rows.append([float(nums[0]), float(nums[1])])

    if not rows:
        raise ValueError(f"{path} 中没有读到有效的两列数值数据：time 和 temperature。")

    data = pd.DataFrame(rows, columns=["time_s", "temperature"])
    # Check the values are within the expected range for temperature (e.g., 0-100 °C)
    
    data["temperature"] = data["temperature"] - 273.15  # 转换为摄氏度
    
    if not ((10 <= data["temperature"]).all() and (data["temperature"] <= 100).all()):
        print(f"WARNING: {series_name} is ignored since contains temperature values outside the expected range 10-100 °C. ")
        print(f"Values: min={data['temperature'].min():.2f}, max={data['temperature'].max():.2f}")
        return None    
    
    data.name = series_name
    return data[["time_s", "temperature"]]


def try_read_out_temperature(filename, series_name, data_dir=CFD_DATA_DIR):
    """读取 CFD .out 文件；如果文件不存在则跳过，避免只缺少某一组数据时整段绘图失败。"""
    try:
        data = read_out_temperature(filename, series_name, data_dir=data_dir)
        
        if data is None:
            print(f"WARNING: {series_name} contains no valid data and is ignored.")
            return None
        
        print(f"Loaded {series_name}: {Path(data_dir) / filename}, rows={len(data)}")
        return data
    
    except Exception as exc:
        print(f"WARNING: {exc}")
        return None

# %%
# Read all data saved in the dir to find out the maximum and minimum temperatures for liquid-cooled BTMS

CFD_DATA_DIR = os.path.join(PROJECT_ROOT, "data","HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705")

print(f"CFD 数据读取目录: {CFD_DATA_DIR}")
cfd_series = {}

for i in range(1, 16): # temperature for each battery cell, 1-15
    filename = f"bat{i}-rfile.out"
    label = f"bat{i:02d}"
    
    print(f"Reading temperature data for battery cell {i} saved in {filename}")
    
    data = try_read_out_temperature(filename, label, data_dir=CFD_DATA_DIR)
    
    if data is not None:
        cfd_series[label] = data
    else: pass
    
# plot all data for selection
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
for label, data in cfd_series.items():
    plt.plot(data["time_s"], data["temperature"], label=label)
    
plt.xlabel("Time [s]")
plt.ylabel("Temperature [°C]")
plt.title("CFD Temperature Data for Each Battery Cell")
plt.legend()
plt.show()
# Out:
# CFD 数据读取目录: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705
# Reading temperature data for battery cell 1 saved in bat1-rfile.out
# Loaded bat01: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat1-rfile.out, rows=1201
# Reading temperature data for battery cell 2 saved in bat2-rfile.out
# Loaded bat02: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat2-rfile.out, rows=1201
# Reading temperature data for battery cell 3 saved in bat3-rfile.out
# Loaded bat03: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat3-rfile.out, rows=1201
# Reading temperature data for battery cell 4 saved in bat4-rfile.out
# Loaded bat04: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat4-rfile.out, rows=1201
# Reading temperature data for battery cell 5 saved in bat5-rfile.out
# Loaded bat05: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat5-rfile.out, rows=1201
# Reading temperature data for battery cell 6 saved in bat6-rfile.out
# Loaded bat06: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat6-rfile.out, rows=1201
# Reading temperature data for battery cell 7 saved in bat7-rfile.out
# Loaded bat07: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat7-rfile.out, rows=1201
# Reading temperature data for battery cell 8 saved in bat8-rfile.out
# Loaded bat08: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat8-rfile.out, rows=1201
# Reading temperature data for battery cell 9 saved in bat9-rfile.out
# Loaded bat09: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat9-rfile.out, rows=1201
# Reading temperature data for battery cell 10 saved in bat10-rfile.out
# Loaded bat10: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat10-rfile.out, rows=1201
# Reading temperature data for battery cell 11 saved in bat11-rfile.out
# Loaded bat11: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat11-rfile.out, rows=1201
# Reading temperature data for battery cell 12 saved in bat12-rfile.out
# Loaded bat12: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat12-rfile.out, rows=1201
# Reading temperature data for battery cell 13 saved in bat13-rfile.out
# Loaded bat13: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat13-rfile.out, rows=1201
# Reading temperature data for battery cell 14 saved in bat14-rfile.out
# Loaded bat14: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat14-rfile.out, rows=1201
# Reading temperature data for battery cell 15 saved in bat15-rfile.out
# Loaded bat15: d:\Workspace\eBATS\data\HP02E030112A2  result_T profile_liquid cooling_CFD_avg T per bat cell_20260705\bat15-rfile.out, rows=1201

# %%
# Data sent by Liu, who find the maximum and minimum temperatures for liquid-cooled BTMS.

CFD_DATA_DIR = os.path.join(PROJECT_ROOT, "data","HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max")

print(f"CFD 数据读取目录: {CFD_DATA_DIR}")

# 要读取并绘制的 CFD 数据文件。
# 新增的两组数据为 min_avg.out 和 max_avg.out，图例分别为 CFD_min_avg 和 CFD_max_avg。
CFD_SERIES_FILES = {
    "CFD_max": "max.out",
    "CFD_min": "min.out",   
    "CFD_max_avg": "max_avg.out",
    "CFD_min_avg": "min_avg.out",
}

# 读取本地 CFD 数据。
cfd_series = []
for label, filename in CFD_SERIES_FILES.items():
    data = try_read_out_temperature(filename, label) 
    if data is not None:
        cfd_series.append((label, data))
# Out:
# CFD 数据读取目录: d:\Workspace\eBATS\data\HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max
# Loaded CFD_max: d:\Workspace\eBATS\data\HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max\max.out, rows=1201
# Loaded CFD_min: d:\Workspace\eBATS\data\HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max\min.out, rows=1201
# Loaded CFD_max_avg: d:\Workspace\eBATS\data\HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max\max_avg.out, rows=1201
# Loaded CFD_min_avg: d:\Workspace\eBATS\data\HP02E030112A1  result_T profile_liquid cooling_CFD_min, max, avg_min, avg_max\min_avg.out, rows=1201

# %%
# Data presented in the paper [[zhang2024PerformanceInvestigation]]  
# plot them as references

# 额外给定数据：BLC-max
BLC_max = np.array([
    [0, 298.16],
    [31.30, 299.30],
    [70.31, 300.34],
    [115.61, 301.12],
    [160.61, 301.74],
    [197.32, 302.22],
    [238.62, 302.60],
    [277.63, 302.88],
    [323.52, 303.12],
    [360.23, 303.27],
    [399.24, 303.39],
    [435.95, 303.47],
    [479.54, 303.50],
    [520.84, 303.51],
    [562.14, 303.52],
    [598.85, 303.53],
    [640.15, 303.54],
    [676.86, 303.55],
    [718.16, 303.56],
    [759.46, 303.58],
    [798.47, 303.63],
    [839.77, 303.72],
    [874.19, 303.86],
    [917.78, 304.08],
    [959.08, 304.39],
    [1002.68, 304.83],
    [1039.39, 305.43],
    [1076.10, 306.18],
    [1119.69, 307.10],
    [1158.70, 308.22],
    [1197.71, 309.47],
], dtype=float)
# 额外给定数据：BLC-min
BLC_min = np.array([
    [0, 298.16],
    [39.76, 298.42],
    [81.92, 298.62],
    [121.98, 298.76],
    [157.81, 298.86],
    [197.87, 298.93],
    [240.04, 299.00],
    [286.44, 299.05],
    [320.18, 299.07],
    [358.14, 299.09],
    [402.42, 299.11],
    [438.28, 299.13],
    [478.34, 299.14],
    [520.52, 299.14],
    [558.49, 299.15],
    [604.89, 299.16],
    [649.17, 299.17],
    [678.70, 299.17],
    [720.87, 299.19],
    [763.05, 299.20],
    [798.91, 299.22],
    [843.19, 299.26],
    [883.26, 299.30],
    [923.32, 299.35],
    [961.27, 299.42],
    [995.01, 299.50],
    [1041.39, 299.63],
    [1079.34, 299.78],
    [1121.50, 299.99],
    [1161.54, 300.24],
    [1200, 300.56],
], dtype=float)

# %%
# read the newest 18650FAC heat-generation profile from the same directory as this notebook

import os
import sys
import numpy as np
import pandas as pd

def normalize_column_name(name):
    """Normalize column names for robust matching."""
    return str(name).strip().lower().replace(" ", "")


def find_column(dataframe, candidates):
    """Find a column by case/space-insensitive matching."""
    normalized = {normalize_column_name(col): col for col in dataframe.columns}
    for candidate in candidates:
        key = normalize_column_name(candidate)
        if key in normalized:
            return normalized[key]
    raise KeyError(f"None of the expected columns were found: {candidates}. Existing columns: {list(dataframe.columns)}")


def numeric_series(dataframe, candidates):
    """Return a numeric Series from the first matching candidate column."""
    col = find_column(dataframe, candidates)
    series = pd.to_numeric(dataframe[col], errors="coerce").dropna()
    return col, series


def first_float_or_none(dataframe, candidates):
    """Read the first numeric value from a candidate column, if it exists."""
    try:
        _, values = numeric_series(dataframe, candidates)
    except KeyError:
        return None
    if values.empty:
        return None
    return float(values.iloc[0])

# %%
file_name = os.path.join(PROJECT_ROOT, "data", "HP02E030111A1  result_Q_liquid cooling_18650FAC.xlsx") 
df = pd.read_excel(file_name, sheet_name="Sheet1")

# Geometry values in the new 18650FAC file.
H_bat_from_file = first_float_or_none(df, ["H(高度)", "H", "height", "Height"])
D_bat_from_file = first_float_or_none(df, ["D(直径)", "D", "diameter", "Diameter"])
H_bat_for_q = H_bat_from_file if H_bat_from_file is not None else 65e-3
D_bat_for_q = D_bat_from_file if D_bat_from_file is not None else 18e-3
V_bat_for_q = np.pi * D_bat_for_q ** 2 / 4.0 * H_bat_for_q

# The newest 18650FAC file has a complete 1200-row Qbat(W) column, so use it
# directly as the single-cell heat-generation power. Do not use Qpack(W), because
# this BLC reproduction uses 15 cells and the total module heat is assembled from
# 15 single-cell values inside the model.
try:
    power_col, power_series = numeric_series(df, ["Qbat(W)", "Qbat", "qbat(W)"])
    power_generation_data = power_series.to_numpy(dtype=float)
    power_source_note = f"{power_col} directly, single-cell heat generation"
except KeyError:
    # Fallback: if a future workbook omits Qbat(W), compute single-cell power from qbat(W/m^3).
    qvol_col, qvol_series = numeric_series(df, ["qbat(W/m^3)", "qbat(W/m3)", "qbat", "qgen(W/m^3)", "qgen"])
    power_generation_data = qvol_series.to_numpy(dtype=float) * V_bat_for_q
    power_col = qvol_col
    power_source_note = f"{qvol_col} multiplied by computed cell volume {V_bat_for_q:.8e} m^3"

# Each row is one 1-second heat-generation interval. 1200 rows => states from 0 to 1200 s.
dt = 1.0
heat_generation_steps = len(power_generation_data)
if heat_generation_steps != 1200:
    print(f"WARNING: heat-generation data contains {heat_generation_steps} rows, not 1200 rows.")

print(f"Loaded heat-generation data from: {file_name}")
print(f"Power source: {power_source_note}")
print(f"Heat-generation intervals: {heat_generation_steps}; simulation end time: {heat_generation_steps*dt:.0f} s")
print(f"Power range: min={np.min(power_generation_data):.6g} W, max={np.max(power_generation_data):.6g} W, mean={np.mean(power_generation_data):.6g} W per cell")
print(f"Battery geometry from file: H={H_bat_from_file} m, D={D_bat_from_file} m, V={V_bat_for_q:.8e} m^3")
# Out:
# Loaded heat-generation data from: d:\Workspace\eBATS\data\HP02E030111A1  result_Q_liquid cooling_18650FAC.xlsx
# Power source: Qbat(W) directly, single-cell heat generation
# Heat-generation intervals: 1200; simulation end time: 1200 s
# Power range: min=0.927676 W, max=2.62219 W, mean=1.27182 W per cell
# Battery geometry from file: H=0.065 m, D=0.018 m, V=1.65404853e-05 m^3

# %%
# Battery parameters for NCR18650PF cylindrical cells used in the Zhang et al. 2024 BLC case.
# The heat-generation file has 1200 rows. With dt = 1 s, the state arrays must have 1201 rows:
# t = 0, 1, 2, ..., 1200 s.

T_bat_init = 25.0  # initial battery temperature in Celsius
cp_bat = 877.24    # J/(kg·K), from the paper table for the 18650 cell
m_bat = 47e-3      # kg, mass of one 18650 cell
D_bat = D_bat_from_file if D_bat_from_file is not None else 18e-3  # m
H_bat = H_bat_from_file if H_bat_from_file is not None else 65e-3  # m

# 15-cell BLC module layout. The 1D liquid model uses one thermal segment per cell.
N_r, N_c = 3, 5
N_cells = N_r * N_c
num_segment = N_cells

A_battery = np.pi * D_bat * H_bat  # lateral surface area of one cylindrical cell, m^2

# %%
num_time_steps = heat_generation_steps + 1

# Adiabatic single-cell temperature rise from the new heat-generation profile.
T_bat_wo_cooling = np.zeros(num_time_steps)
T_bat_wo_cooling[0] = T_bat_init

for i in range(1, num_time_steps):
    # power_generation_data[i-1] is the heat generated during interval (i-1, i].
    dT = (power_generation_data[i - 1] * dt) / (m_bat * cp_bat)
    T_bat_wo_cooling[i] = T_bat_wo_cooling[i - 1] + dT

print(
    f"Battery setup: N_cells={N_cells}, m_bat={m_bat:.6g} kg, cp_bat={cp_bat:.6g} J/(kg·K), "
    f"D_bat={D_bat:.6g} m, H_bat={H_bat:.6g} m"
)
print(f"Simulation time grid: {num_time_steps} state points, t = 0 to {(num_time_steps-1)*dt:.0f} s")
# Out:
# Battery setup: N_cells=15, m_bat=0.047 kg, cp_bat=877.24 J/(kg·K), D_bat=0.018 m, H_bat=0.065 m
# Simulation time grid: 1201 state points, t = 0 to 1200 s

# %%
# Initial conditions and BLC liquid-cooling parameters
# BLC replication case from section 3.1: Tamb = 25 °C, Tin = 25 °C, Fc = 240 mL/min.
# Only bottom liquid cooling is retained; heat-pipe material data are intentionally not used.

import numpy as np

# channel geometries

D_channel = 4e-3      # m, circular channel diameter / hydraulic diameter
D_h = D_channel       # m, hydraulic diameter for circular channel, same as diameter
# Total fluid-domain length: 126 + 126 + 144 + 144 + 3*pi*8 mm
# L_channel_total = (126.0 + 126.0 + 144.0 + 144.0 + 3.0 * np.pi * 8.0) * 1e-3
L_channel_total = 144e-3 * 4 # for simplicity, use 4 straight segments of 144 mm each, ignoring the short 126 mm segments and the bends, this is a liquid channel with three U-bends. # Channel and heat-transfer areas
N_cool_seg = 20 # for the above channel layout, use 20 segments for the 1D model to balance resolution and computational cost.

A_channel_cross = np.pi * D_channel ** 2 / 4.0
P_channel_wet = np.pi * D_channel
# A_liq_total = P_channel_wet * L_channel_total / 2 # m^2, total wetted area of the channel; divide by 2 because only the upper half of the channel is in contact with the cell and thus participates in heat transfer with the liquid coolant.
A_liq_total = P_channel_wet * L_channel_total # m^2, total wetted area of the channel; assume all of it participates in heat transfer with the liquid coolant.

# Plate material for BLC: aluminum element/cold plate data from the paper.
k_plate = 202.4   # W/(m·K)
cp_plate = 871.0  # J/(kg·K), recorded only; cold-plate heat capacity is neglected
rho_plate = 2719.0 # kg/m^3, recorded only; cold-plate heat capacity is neglected

# Plate geometry for BLC
W_plate = 76e-3 # m, cold plate width, same as the paper
L_plate = 138e-3 # m, cold plate length, same as the paper
A_plate_total = W_plate * L_plate # m^2, total area of the cold

# A_HT_all = A_plate_total 
A_HT_all = A_liq_total

A_HT_seg = A_HT_all / N_cool_seg # m^2, heat transfer area for each segment 

# Liquid coolant settings
T_liq_in = 25.0  # °C
T_liq_in_K = T_liq_in + 273.15
p_liq = 101325  # Pa
fluid_liq = "Water"

# Coolant properties from the paper table
rho_liq_const = 998.2   # kg/m^3
cp_liq_const = 4182.0   # J/(kg·K)
k_liq_const = 0.6       # W/(m·K)

# Paper flow rate Fc = 240 mL/min. Convert volumetric flow rate to mass flow rate.
Fc_mL_min = 240.0
vol_flow_m3_s = Fc_mL_min * 1e-6 / 60.0  # 1 mL = 1e-6 m^3
m_dot_liq = rho_liq_const * vol_flow_m3_s # kg/s

V_cool_in = m_dot_liq / (rho_liq_const * A_channel_cross)
V_cool_char = V_cool_in

# print(f"u_cool_in = {u_cool_in}")

# Defines a map for the correspondence between the battery cell and liquid segment indices. 
# e.g., for 3*5 battery cells and a single liquid channel, if the liquid channel includes threes U-turns, the liquid channel can be devided into 20 segments, and thus, for the battery cells in the middle row, each cell corresponds to 2 coolant segments. 

# define the indices for N_seg = 15 battery cells in the 3*5 layout
# The ordering of coolant should follow the flow direction. 
cell_to_cool_map = {
    0: (0,),
    1: (1,),
    2: (2,),
    3: (3,),
    4: (4,),
    5: (9, 10),  # cell 5 (the first cell in the second row) corresponds to segements 9 and 10
    6: (8, 11),  # cell 6 corresponds to segements 6 and 11
    7: (7, 12),  # cell 7 corresponds to segements 7 and 12
    8: (6, 13),  # cell 8 corresponds to segements 6 and 13
    9: (5, 14),  # cell 9 corresponds to segements 5 and 14
    10: (19,),
    11: (18,),
    12: (17,),
    13: (16,),
    14: (15,),
}

# %%
sys.path.append(PROJECT_ROOT)
import lib.BTMS_model as BTMS_model

# Dynamic viscosity is required for Re/Pr/Nu but is not listed in the paper table.
# Use CoolProp for viscosity only when available; otherwise use water viscosity near 25 °C.
try:
    import CoolProp.CoolProp as CP
    mu_liq_const = CP.PropsSI("V", "T", T_liq_in_K, "P", p_liq, fluid_liq)
    prop_source = "paper rho/cp/k; CoolProp viscosity"
except Exception as exc:
    mu_liq_const = 8.90e-4  # Pa·s, approximate water viscosity at 25 °C
    prop_source = f"paper rho/cp/k; fallback viscosity because CoolProp is unavailable: {exc}"

# Liquid-side Reynolds, Nusselt, h and resistances. Nu correlation remains unchanged.
Pr_liq = cp_liq_const * mu_liq_const / k_liq_const
Re_liq = m_dot_liq * D_h / (mu_liq_const * A_channel_cross)
Nu_liq = BTMS_model.liquid_nusselt_number(Re_liq, Pr_liq, heating=False)
htc_liq = Nu_liq * k_liq_const / D_h

k_plate = 202.4   # W/(m·K), aluminum cold plate conductivity from the paper
t_plate = 8e-3    # m, cold plate thickness from the paper
R_plate = t_plate / k_plate  # thermal resistance through the plate; 

htc_global = 1 / (R_plate + 1 / htc_liq)  # global heat transfer coefficient combining conduction and convection; 

debug = True  # set to True to print detailed parameters for verification

# print the above parameters for verification
print(f"Liquid coolant properties: {prop_source}")
print(f"Liquid inlet temperature: {T_liq_in:.2f} °C")
print(f"Mass flow rate: {m_dot_liq:.6g} kg/s")
print(f"Reynolds number: {Re_liq:.6g}")
print(f"Nusselt number: {Nu_liq:.6g}")
print(f"Convective heat transfer coefficient: h = {htc_liq:.6g} W/(m^2·K)")
print(f"Total channel length: {L_channel_total:.6g} m, total wetted perimeter: {P_channel_wet:.6g} m, total heat transfer area: {A_liq_total:.6g} m^2") 
print(f"Heat transfer area per segment: {A_HT_seg:.6g} m^2")
# Out:
# Liquid coolant properties: paper rho/cp/k; CoolProp viscosity
# Liquid inlet temperature: 25.00 °C
# Mass flow rate: 0.0039928 kg/s
# Reynolds number: 1428
# Nusselt number: 4.36
# Convective heat transfer coefficient: h = 654 W/(m^2·K)
# Total channel length: 0.576 m, total wetted perimeter: 0.0125664 m, total heat transfer area: 0.00723823 m^2
# Heat transfer area per segment: 0.000361911 m^2

# %%
# Use a 0D model to calcualte the coolant outlet temperature as a reference

T_bat_history_0D = np.zeros(num_time_steps)
T_cool_history_0D = np.zeros(num_time_steps)
T_bat_history_0D[0] = T_bat_init
T_cool_history_0D[0] = T_liq_in
Q_cool_history_0D = np.zeros(num_time_steps)

for i in range(1, num_time_steps):
    
    T_cool_out_guess = T_cool_history_0D[i-1]
    # T_cool_bar_guess = 0.5 * (T_liq_in + T_cool_out_guess)
    T_cool_bar = T_liq_in
    T_bat_pre = T_bat_history_0D[i - 1]
    Q_HT = htc_global * A_HT_all * (T_bat_pre - T_cool_bar)  # heat transfer from battery to coolant
    
    dT_bat = (power_generation_data[i-1] * N_cells - Q_HT) / (m_bat * cp_bat * N_cells)  # temperature change in the battery
    
    dT_cool = Q_HT / (m_dot_liq * cp_liq_const)  # temperature change in the coolant
    
    T_cool_out = T_liq_in + dT_cool
    T_bat_history_0D[i] = T_bat_pre + dT_bat
    T_cool_history_0D[i] = T_cool_out
    Q_cool_history_0D[i] = Q_HT

# %%
import lib.BTMS_model as BTMS_model

t = 0 # initialize time variable
T_bat_history = np.empty(num_time_steps, dtype=object) # to store battery temperature history
T_cool_history = np.empty(num_time_steps, dtype=object) # to store coolant temperature history

Q_bat_history = np.empty(num_time_steps) # to store battery heat generation history
Q_cool_history = np.empty(num_time_steps) # to store coolant heat absorption history
Q_res_history = np.empty(num_time_steps) # to store residual history for debugging
Q_cool_history_detailed = np.empty(num_time_steps, dtype=object) # to store detailed coolant heat transfer history for each cell

for i in range(num_time_steps):
    T_bat_history[i] = np.ones(N_cells) * T_bat_init # initialize battery temperature history for this time step
    T_cool_history[i] = np.ones(N_cool_seg) * T_liq_in # initialize coolant temperature history for this time step
    Q_bat_history[i] = 0 # initialize battery heat generation history for this time step
    Q_cool_history[i] = 0 # initialize coolant heat absorption history for this time step
    Q_res_history[i] = 0 # initialize residual history for this time step
    Q_cool_history_detailed[i] = np.zeros(N_cells) # initialize detailed coolant heat transfer history for this time step

debug = False
use_global_HTC = False #True
upwind_scheme = True

for i in range(1, num_time_steps):
# for i in range(0, 2):
       
    Q_cool_HT = 0 # initialize cooling power for this time step
    
    print(f"*** Time step {i}: t = {t:.0f} s ***")   
    
    T_bat_pre = T_bat_history[i - 1]  # battery temperature from the previous time step     
    T_cool_pre = T_cool_history[i - 1]  # coolant temperature from the previous time step
    
    # determine the convective HTC, where the coolant properties are calculdated based on the average temperature of the coolant at current time step. 
   
    # evaluate the local HTC in an segement-wise manner 
    
    T_dist_guess = np.linspace(T_liq_in, T_cool_history_0D[i], num_segment+1) # an initial guess for the temperature distribution of the coolant along the flow direction 
    htc_seg = np.zeros(num_segment) # to store the convective heat transfer coefficient for each segment, adjust as needed
    
    for j in range(num_segment):
        if not use_global_HTC:
            T_m_seg = (T_dist_guess[j] + T_dist_guess[j+1]) / 2 
            # T_m_seg = T_dist_guess[j]
            T_m_seg_k = T_m_seg + 273.15 # convert to Kelvin
            # calculate the Prandtl number for the liquid at the average coolant temperature
            mu_m = CP.PropsSI('V', 'T', T_m_seg_k, 'P', p_liq, fluid_liq) # dynamic viscosity of the liquid at the average coolant temperature in kg/(m·s)
            rho_m = CP.PropsSI('D', 'T', T_m_seg_k, 'P', p_liq, fluid_liq) # density of the liquid at the average coolant temperature in kg/m^3
            cp_m = CP.PropsSI('C', 'T', T_m_seg_k, 'P', p_liq, fluid_liq) # specific heat capacity of the liquid at the average coolant temperature in J/(kg·K)
            k_m = CP.PropsSI('L', 'T', T_m_seg_k, 'P', p_liq, fluid_liq) # thermal conductivity of the liquid at the average coolant temperature in W/(m·K)
            Pr_air_m = cp_m * mu_m / k_m # Prandtl number for the liquid at the average coolant temperature
            
            # calculate the Reynolds number for the liquid flow over the battery at the average coolant temperature
            Re_m = (m_dot_liq * D_h) / (mu_m * A_channel_cross)
            
            Nu_m = BTMS_model.liquid_nusselt_number(Re_m, Pr_air_m)  # example call, adjust as needed

            htc_liq_seg = (Nu_m * k_m) / D_h # convective HTC   
        
            htc_seg[j] = 1 / ( 1 / htc_liq_seg + R_plate)
            
        else:
            htc_seg[j] = htc_global
        
    args = {
        "dt": dt,
        "num_seg_bat": N_cells,
        "num_seg_cool": N_cool_seg,
        "T_bat_pre": T_bat_pre,
        "T_cool_pre": T_cool_pre,
        "u_cool_in": V_cool_in,
        "p_cool": p_liq,
        "fluid_cool": fluid_liq,
        "A_HT_seg": A_HT_seg,
        "A_cool_cs": A_channel_cross,
        "m_bat": m_bat,
        "cp_bat": cp_bat,
        "D_bat": D_bat,
        "T_cool_in": T_liq_in,
        "is_cool": True,  # BLC case: cooling is always on
        "htc_cool": htc_seg,  # use the calculated convective heat transfer coefficient for the liquid coolant
        "cp_cool": cp_liq_const,  # use constant specific heat capacity for simplicity; adjust as needed
        "rho_cool": rho_liq_const,  # use constant density for simplicity; adjust as needed
        "Q_gen": power_generation_data[i - 1],  # heat generated in the battery during this time step
        "upwind_scheme": upwind_scheme,
        "num_cell_seg": 1.0,
        "cell_to_cool_map": cell_to_cool_map
    }
    
    T_dist = BTMS_model.solve_coolant_temperature_distribution(
        cal_residual=True, # 
        args=args,
        tol = 1e-3,
        maxiter = 1000,
        debug = debug            
    )   
    
    T_cool = T_dist[0:N_cool_seg]
    T_bat = T_dist[N_cool_seg:]    
    
    Q_cool_HT, Q_cool_change, Q_bat = BTMS_model.cal_energy_balance(T_dist, args)

    Q_bat_history[i] = sum(Q_bat)
    Q_cool_history[i] = sum(Q_cool_HT)
    Q_cool_history_detailed[i] = Q_cool_HT
    
    # identify the segment with minimum heat transfer for debugging; this segment may indicate a bottleneck in the cooling performance
    min_Q_cool_HT_seg = np.argmin(Q_cool_HT)
    print(f"Minimum heat transfer segment: {min_Q_cool_HT_seg}, Q_cool_HT = {Q_cool_HT[min_Q_cool_HT_seg]:.6g} W")
    
    Q_res = abs(power_generation_data[i - 1] * N_cells - sum(Q_bat) - sum(Q_cool_HT))  # residual based on battery heat generation and coolant heat transfer; adjust as needed
    Q_res_history[i] = Q_res
    
    T_bat_history[i] = T_bat
    T_cool_history[i] = T_cool
    t = t + dt # update time variable
# Out:
# *** Time step 1: t = 0 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.00661407 W
# *** Time step 2: t = 1 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0131116 W
# *** Time step 3: t = 2 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.019602 W
# *** Time step 4: t = 3 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0260088 W
# *** Time step 5: t = 4 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0323938 W
# *** Time step 6: t = 5 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0387203 W
# *** Time step 7: t = 6 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0449854 W
# *** Time step 8: t = 7 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0511834 W
# *** Time step 9: t = 8 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0572981 W
# *** Time step 10: t = 9 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0633608 W
# *** Time step 11: t = 10 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0693766 W
# *** Time step 12: t = 11 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0753471 W
# *** Time step 13: t = 12 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0812842 W
# *** Time step 14: t = 13 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0871668 W
# *** Time step 15: t = 14 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0930073 W
# *** Time step 16: t = 15 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.0988128 W
# *** Time step 17: t = 16 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.104571 W
# *** Time step 18: t = 17 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.11028 W
# *** Time step 19: t = 18 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.115938 W
# *** Time step 20: t = 19 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.121555 W
# *** Time step 21: t = 20 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.127144 W
# *** Time step 22: t = 21 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.132704 W
# *** Time step 23: t = 22 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.138227 W
# *** Time step 24: t = 23 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.143683 W
# *** Time step 25: t = 24 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.149141 W
# *** Time step 26: t = 25 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.154575 W
# *** Time step 27: t = 26 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.15993 W
# *** Time step 28: t = 27 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.165248 W
# *** Time step 29: t = 28 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.170543 W
# *** Time step 30: t = 29 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.175786 W
# *** Time step 31: t = 30 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.18097 W
# *** Time step 32: t = 31 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.186138 W
# *** Time step 33: t = 32 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.191254 W
# *** Time step 34: t = 33 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.196336 W
# *** Time step 35: t = 34 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.201395 W
# *** Time step 36: t = 35 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.206392 W
# *** Time step 37: t = 36 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.211382 W
# *** Time step 38: t = 37 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.21632 W
# *** Time step 39: t = 38 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.221217 W
# *** Time step 40: t = 39 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.226089 W
# *** Time step 41: t = 40 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.230921 W
# *** Time step 42: t = 41 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.235713 W
# *** Time step 43: t = 42 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.240489 W
# *** Time step 44: t = 43 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.245207 W
# *** Time step 45: t = 44 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.249899 W
# *** Time step 46: t = 45 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.254559 W
# *** Time step 47: t = 46 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.25918 W
# *** Time step 48: t = 47 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.263778 W
# *** Time step 49: t = 48 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.268342 W
# *** Time step 50: t = 49 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.272868 W
# *** Time step 51: t = 50 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.277353 W
# *** Time step 52: t = 51 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.281815 W
# *** Time step 53: t = 52 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.286253 W
# *** Time step 54: t = 53 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.290645 W
# *** Time step 55: t = 54 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.295009 W
# *** Time step 56: t = 55 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.299337 W
# *** Time step 57: t = 56 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.30365 W
# *** Time step 58: t = 57 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.307909 W
# *** Time step 59: t = 58 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.312161 W
# *** Time step 60: t = 59 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.316363 W
# *** Time step 61: t = 60 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.320542 W
# *** Time step 62: t = 61 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.324682 W
# *** Time step 63: t = 62 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.328806 W
# *** Time step 64: t = 63 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.332903 W
# *** Time step 65: t = 64 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.336958 W
# *** Time step 66: t = 65 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.340994 W
# *** Time step 67: t = 66 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.344983 W
# *** Time step 68: t = 67 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.348957 W
# *** Time step 69: t = 68 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.352898 W
# *** Time step 70: t = 69 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.356819 W
# *** Time step 71: t = 70 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.360708 W
# *** Time step 72: t = 71 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.36457 W
# *** Time step 73: t = 72 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.36839 W
# *** Time step 74: t = 73 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.3722 W
# *** Time step 75: t = 74 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.375984 W
# *** Time step 76: t = 75 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.379721 W
# *** Time step 77: t = 76 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.383447 W
# *** Time step 78: t = 77 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.387146 W
# *** Time step 79: t = 78 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.390814 W
# *** Time step 80: t = 79 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.394464 W
# *** Time step 81: t = 80 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.398072 W
# *** Time step 82: t = 81 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.401664 W
# *** Time step 83: t = 82 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.405223 W
# *** Time step 84: t = 83 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.408762 W
# *** Time step 85: t = 84 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.41228 W
# *** Time step 86: t = 85 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.415775 W
# *** Time step 87: t = 86 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.419231 W
# *** Time step 88: t = 87 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.422667 W
# *** Time step 89: t = 88 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.426084 W
# *** Time step 90: t = 89 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.429472 W
# *** Time step 91: t = 90 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.432832 W
# *** Time step 92: t = 91 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.436181 W
# *** Time step 93: t = 92 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.439501 W
# *** Time step 94: t = 93 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.442805 W
# *** Time step 95: t = 94 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.446074 W
# *** Time step 96: t = 95 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.449323 W
# *** Time step 97: t = 96 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.452553 W
# *** Time step 98: t = 97 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.455745 W
# *** Time step 99: t = 98 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.458929 W
# *** Time step 100: t = 99 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.462084 W
# *** Time step 101: t = 100 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.465218 W
# *** Time step 102: t = 101 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.46834 W
# *** Time step 103: t = 102 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.471428 W
# *** Time step 104: t = 103 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.474503 W
# *** Time step 105: t = 104 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.477544 W
# *** Time step 106: t = 105 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.480568 W
# *** Time step 107: t = 106 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.483566 W
# *** Time step 108: t = 107 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.486555 W
# *** Time step 109: t = 108 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.489525 W
# *** Time step 110: t = 109 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.492462 W
# *** Time step 111: t = 110 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.495384 W
# *** Time step 112: t = 111 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.498293 W
# *** Time step 113: t = 112 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.501174 W
# *** Time step 114: t = 113 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.504037 W
# *** Time step 115: t = 114 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.506869 W
# *** Time step 116: t = 115 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.50969 W
# *** Time step 117: t = 116 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.512485 W
# *** Time step 118: t = 117 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.51527 W
# *** Time step 119: t = 118 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.51803 W
# *** Time step 120: t = 119 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.52078 W
# *** Time step 121: t = 120 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.523505 W
# *** Time step 122: t = 121 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.526209 W
# *** Time step 123: t = 122 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.528907 W
# *** Time step 124: t = 123 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.53157 W
# *** Time step 125: t = 124 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.534222 W
# *** Time step 126: t = 125 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.536857 W
# *** Time step 127: t = 126 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.539466 W
# *** Time step 128: t = 127 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.542058 W
# *** Time step 129: t = 128 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.544648 W
# *** Time step 130: t = 129 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.547206 W
# *** Time step 131: t = 130 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.549754 W
# *** Time step 132: t = 131 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.552271 W
# *** Time step 133: t = 132 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.554787 W
# *** Time step 134: t = 133 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.556366 W
# *** Time step 135: t = 134 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.559195 W
# *** Time step 136: t = 135 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.561953 W
# *** Time step 137: t = 136 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.56457 W
# *** Time step 138: t = 137 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.567167 W
# *** Time step 139: t = 138 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.569538 W
# *** Time step 140: t = 139 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.571955 W
# *** Time step 141: t = 140 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.574472 W
# *** Time step 142: t = 141 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.577059 W
# *** Time step 143: t = 142 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.579314 W
# *** Time step 144: t = 143 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.581802 W
# *** Time step 145: t = 144 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.584267 W
# *** Time step 146: t = 145 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.5865 W
# *** Time step 147: t = 146 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.588705 W
# *** Time step 148: t = 147 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.590992 W
# *** Time step 149: t = 148 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.593356 W
# *** Time step 150: t = 149 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.595477 W
# *** Time step 151: t = 150 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.597762 W
# *** Time step 152: t = 151 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.599833 W
# *** Time step 153: t = 152 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.601975 W
# *** Time step 154: t = 153 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.604167 W
# *** Time step 155: t = 154 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.606321 W
# *** Time step 156: t = 155 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.60847 W
# *** Time step 157: t = 156 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.610611 W
# *** Time step 158: t = 157 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.612739 W
# *** Time step 159: t = 158 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.614855 W
# *** Time step 160: t = 159 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.616947 W
# *** Time step 161: t = 160 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.619015 W
# *** Time step 162: t = 161 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.621093 W
# *** Time step 163: t = 162 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.623156 W
# *** Time step 164: t = 163 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.625189 W
# *** Time step 165: t = 164 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.627221 W
# *** Time step 166: t = 165 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.629229 W
# *** Time step 167: t = 166 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.631248 W
# *** Time step 168: t = 167 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.633231 W
# *** Time step 169: t = 168 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.635219 W
# *** Time step 170: t = 169 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.637173 W
# *** Time step 171: t = 170 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.639138 W
# *** Time step 172: t = 171 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.641085 W
# *** Time step 173: t = 172 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.643014 W
# *** Time step 174: t = 173 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.644926 W
# *** Time step 175: t = 174 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.646829 W
# *** Time step 176: t = 175 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.648717 W
# *** Time step 177: t = 176 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.650606 W
# *** Time step 178: t = 177 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.652473 W
# *** Time step 179: t = 178 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.654334 W
# *** Time step 180: t = 179 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.654624 W
# *** Time step 181: t = 180 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.656518 W
# *** Time step 182: t = 181 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.658394 W
# *** Time step 183: t = 182 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.660318 W
# *** Time step 184: t = 183 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.66196 W
# *** Time step 185: t = 184 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.663868 W
# *** Time step 186: t = 185 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.665633 W
# *** Time step 187: t = 186 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.66757 W
# *** Time step 188: t = 187 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.669351 W
# *** Time step 189: t = 188 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.671192 W
# *** Time step 190: t = 189 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.67299 W
# *** Time step 191: t = 190 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.674787 W
# *** Time step 192: t = 191 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.676597 W
# *** Time step 193: t = 192 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.678305 W
# *** Time step 194: t = 193 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.680165 W
# *** Time step 195: t = 194 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.682001 W
# *** Time step 196: t = 195 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.683815 W
# *** Time step 197: t = 196 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.685531 W
# *** Time step 198: t = 197 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.687315 W
# *** Time step 199: t = 198 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.688976 W
# *** Time step 200: t = 199 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.690695 W
# *** Time step 201: t = 200 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.692324 W
# *** Time step 202: t = 201 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.694048 W
# *** Time step 203: t = 202 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.695765 W
# *** Time step 204: t = 203 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.697465 W
# *** Time step 205: t = 204 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.699126 W
# *** Time step 206: t = 205 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.70074 W
# *** Time step 207: t = 206 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.70237 W
# *** Time step 208: t = 207 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.703994 W
# *** Time step 209: t = 208 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.705615 W
# *** Time step 210: t = 209 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.707236 W
# *** Time step 211: t = 210 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.70885 W
# *** Time step 212: t = 211 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.710418 W
# *** Time step 213: t = 212 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.711981 W
# *** Time step 214: t = 213 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.713559 W
# *** Time step 215: t = 214 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.715085 W
# *** Time step 216: t = 215 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.716556 W
# *** Time step 217: t = 216 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.718108 W
# *** Time step 218: t = 217 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.719518 W
# *** Time step 219: t = 218 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.72093 W
# *** Time step 220: t = 219 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.722362 W
# *** Time step 221: t = 220 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.723934 W
# *** Time step 222: t = 221 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.725273 W
# *** Time step 223: t = 222 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.726799 W
# *** Time step 224: t = 223 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.728346 W
# *** Time step 225: t = 224 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.729841 W
# *** Time step 226: t = 225 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.731147 W
# *** Time step 227: t = 226 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.732464 W
# *** Time step 228: t = 227 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.733799 W
# *** Time step 229: t = 228 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.735139 W
# *** Time step 230: t = 229 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.736566 W
# *** Time step 231: t = 230 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.737914 W
# *** Time step 232: t = 231 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.739252 W
# *** Time step 233: t = 232 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.740535 W
# *** Time step 234: t = 233 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.741844 W
# *** Time step 235: t = 234 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.74319 W
# *** Time step 236: t = 235 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.744531 W
# *** Time step 237: t = 236 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.745858 W
# *** Time step 238: t = 237 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.747177 W
# *** Time step 239: t = 238 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.748482 W
# *** Time step 240: t = 239 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.7498 W
# *** Time step 241: t = 240 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.751094 W
# *** Time step 242: t = 241 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.752382 W
# *** Time step 243: t = 242 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.753664 W
# *** Time step 244: t = 243 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.754952 W
# *** Time step 245: t = 244 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.756222 W
# *** Time step 246: t = 245 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.757485 W
# *** Time step 247: t = 246 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.758731 W
# *** Time step 248: t = 247 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.759976 W
# *** Time step 249: t = 248 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.761202 W
# *** Time step 250: t = 249 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.762494 W
# *** Time step 251: t = 250 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.76374 W
# *** Time step 252: t = 251 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.764988 W
# *** Time step 253: t = 252 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.766209 W
# *** Time step 254: t = 253 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.767408 W
# *** Time step 255: t = 254 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.76861 W
# *** Time step 256: t = 255 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.769815 W
# *** Time step 257: t = 256 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.771 W
# *** Time step 258: t = 257 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.772187 W
# *** Time step 259: t = 258 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.773367 W
# *** Time step 260: t = 259 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.774543 W
# *** Time step 261: t = 260 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.775719 W
# *** Time step 262: t = 261 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.776871 W
# *** Time step 263: t = 262 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.778023 W
# *** Time step 264: t = 263 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.779186 W
# *** Time step 265: t = 264 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.780328 W
# *** Time step 266: t = 265 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.781468 W
# *** Time step 267: t = 266 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.782582 W
# *** Time step 268: t = 267 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.783724 W
# *** Time step 269: t = 268 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.784834 W
# *** Time step 270: t = 269 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.785955 W
# *** Time step 271: t = 270 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.78705 W
# *** Time step 272: t = 271 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.788162 W
# *** Time step 273: t = 272 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.789245 W
# *** Time step 274: t = 273 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.79034 W
# *** Time step 275: t = 274 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.79143 W
# *** Time step 276: t = 275 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.792504 W
# *** Time step 277: t = 276 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.793576 W
# *** Time step 278: t = 277 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.794653 W
# *** Time step 279: t = 278 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.795712 W
# *** Time step 280: t = 279 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.796774 W
# *** Time step 281: t = 280 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.797826 W
# *** Time step 282: t = 281 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.798876 W
# *** Time step 283: t = 282 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.799909 W
# *** Time step 284: t = 283 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.800953 W
# *** Time step 285: t = 284 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.801987 W
# *** Time step 286: t = 285 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.803005 W
# *** Time step 287: t = 286 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.804028 W
# *** Time step 288: t = 287 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.805035 W
# *** Time step 289: t = 288 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.806057 W
# *** Time step 290: t = 289 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.80705 W
# *** Time step 291: t = 290 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.808056 W
# *** Time step 292: t = 291 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.809056 W
# *** Time step 293: t = 292 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.810042 W
# *** Time step 294: t = 293 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.81103 W
# *** Time step 295: t = 294 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.812 W
# *** Time step 296: t = 295 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.812977 W
# *** Time step 297: t = 296 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.813944 W
# *** Time step 298: t = 297 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.814923 W
# *** Time step 299: t = 298 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.815876 W
# *** Time step 300: t = 299 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.816828 W
# *** Time step 301: t = 300 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.81778 W
# *** Time step 302: t = 301 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.818728 W
# *** Time step 303: t = 302 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.819668 W
# *** Time step 304: t = 303 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.820596 W
# *** Time step 305: t = 304 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.821537 W
# *** Time step 306: t = 305 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.822461 W
# *** Time step 307: t = 306 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.823376 W
# *** Time step 308: t = 307 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.824293 W
# *** Time step 309: t = 308 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.825205 W
# *** Time step 310: t = 309 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.826114 W
# *** Time step 311: t = 310 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.827017 W
# *** Time step 312: t = 311 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.827902 W
# *** Time step 313: t = 312 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.828795 W
# *** Time step 314: t = 313 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.829693 W
# *** Time step 315: t = 314 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.830583 W
# *** Time step 316: t = 315 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.831448 W
# *** Time step 317: t = 316 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.832323 W
# *** Time step 318: t = 317 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.833201 W
# *** Time step 319: t = 318 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.834056 W
# *** Time step 320: t = 319 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.834923 W
# *** Time step 321: t = 320 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.835776 W
# *** Time step 322: t = 321 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.836627 W
# *** Time step 323: t = 322 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.837488 W
# *** Time step 324: t = 323 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.838325 W
# *** Time step 325: t = 324 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.839162 W
# *** Time step 326: t = 325 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.840003 W
# *** Time step 327: t = 326 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.840834 W
# *** Time step 328: t = 327 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.841654 W
# *** Time step 329: t = 328 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.842475 W
# *** Time step 330: t = 329 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.843293 W
# *** Time step 331: t = 330 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.84411 W
# *** Time step 332: t = 331 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.844916 W
# *** Time step 333: t = 332 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.845721 W
# *** Time step 334: t = 333 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.846514 W
# *** Time step 335: t = 334 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.847314 W
# *** Time step 336: t = 335 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.848105 W
# *** Time step 337: t = 336 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.848889 W
# *** Time step 338: t = 337 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.849678 W
# *** Time step 339: t = 338 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.850453 W
# *** Time step 340: t = 339 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.851229 W
# *** Time step 341: t = 340 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.851992 W
# *** Time step 342: t = 341 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.852756 W
# *** Time step 343: t = 342 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.853526 W
# *** Time step 344: t = 343 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.854281 W
# *** Time step 345: t = 344 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.855032 W
# *** Time step 346: t = 345 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.855779 W
# *** Time step 347: t = 346 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.856524 W
# *** Time step 348: t = 347 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.857275 W
# *** Time step 349: t = 348 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.857996 W
# *** Time step 350: t = 349 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.858732 W
# *** Time step 351: t = 350 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.859458 W
# *** Time step 352: t = 351 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.860192 W
# *** Time step 353: t = 352 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.860913 W
# *** Time step 354: t = 353 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.861626 W
# *** Time step 355: t = 354 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.862336 W
# *** Time step 356: t = 355 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.863047 W
# *** Time step 357: t = 356 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.863749 W
# *** Time step 358: t = 357 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.864455 W
# *** Time step 359: t = 358 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.865151 W
# *** Time step 360: t = 359 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.865831 W
# *** Time step 361: t = 360 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.866532 W
# *** Time step 362: t = 361 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.867208 W
# *** Time step 363: t = 362 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.867899 W
# *** Time step 364: t = 363 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.868568 W
# *** Time step 365: t = 364 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.869233 W
# *** Time step 366: t = 365 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.869912 W
# *** Time step 367: t = 366 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.870566 W
# *** Time step 368: t = 367 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.871233 W
# *** Time step 369: t = 368 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.871883 W
# *** Time step 370: t = 369 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.872544 W
# *** Time step 371: t = 370 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.873189 W
# *** Time step 372: t = 371 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.873837 W
# *** Time step 373: t = 372 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.874477 W
# *** Time step 374: t = 373 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.875111 W
# *** Time step 375: t = 374 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.875752 W
# *** Time step 376: t = 375 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.876372 W
# *** Time step 377: t = 376 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.876999 W
# *** Time step 378: t = 377 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.877621 W
# *** Time step 379: t = 378 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.878234 W
# *** Time step 380: t = 379 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.878849 W
# *** Time step 381: t = 380 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.879464 W
# *** Time step 382: t = 381 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.880066 W
# *** Time step 383: t = 382 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.88068 W
# *** Time step 384: t = 383 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.881275 W
# *** Time step 385: t = 384 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.881873 W
# *** Time step 386: t = 385 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.882462 W
# *** Time step 387: t = 386 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.883064 W
# *** Time step 388: t = 387 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.883638 W
# *** Time step 389: t = 388 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.884221 W
# *** Time step 390: t = 389 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.884792 W
# *** Time step 391: t = 390 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.885384 W
# *** Time step 392: t = 391 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.885968 W
# *** Time step 393: t = 392 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.88652 W
# *** Time step 394: t = 393 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.887083 W
# *** Time step 395: t = 394 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.887645 W
# *** Time step 396: t = 395 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.888208 W
# *** Time step 397: t = 396 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.888757 W
# *** Time step 398: t = 397 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.889307 W
# *** Time step 399: t = 398 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.889849 W
# *** Time step 400: t = 399 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.890395 W
# *** Time step 401: t = 400 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.890932 W
# *** Time step 402: t = 401 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.891464 W
# *** Time step 403: t = 402 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.891998 W
# *** Time step 404: t = 403 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.89253 W
# *** Time step 405: t = 404 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.89306 W
# *** Time step 406: t = 405 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.893577 W
# *** Time step 407: t = 406 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.8941 W
# *** Time step 408: t = 407 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.894619 W
# *** Time step 409: t = 408 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.895133 W
# *** Time step 410: t = 409 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.895636 W
# *** Time step 411: t = 410 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.896141 W
# *** Time step 412: t = 411 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.896651 W
# *** Time step 413: t = 412 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.89714 W
# *** Time step 414: t = 413 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.897625 W
# *** Time step 415: t = 414 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.898119 W
# *** Time step 416: t = 415 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.898606 W
# *** Time step 417: t = 416 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.89909 W
# *** Time step 418: t = 417 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.899566 W
# *** Time step 419: t = 418 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.900037 W
# *** Time step 420: t = 419 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.90051 W
# *** Time step 421: t = 420 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.900976 W
# *** Time step 422: t = 421 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.901442 W
# *** Time step 423: t = 422 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.901903 W
# *** Time step 424: t = 423 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.902332 W
# *** Time step 425: t = 424 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.90279 W
# *** Time step 426: t = 425 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.903242 W
# *** Time step 427: t = 426 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.903692 W
# *** Time step 428: t = 427 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.904141 W
# *** Time step 429: t = 428 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.904582 W
# *** Time step 430: t = 429 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.905022 W
# *** Time step 431: t = 430 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.905459 W
# *** Time step 432: t = 431 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.905892 W
# *** Time step 433: t = 432 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.90632 W
# *** Time step 434: t = 433 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.906745 W
# *** Time step 435: t = 434 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.907167 W
# *** Time step 436: t = 435 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.907584 W
# *** Time step 437: t = 436 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.907996 W
# *** Time step 438: t = 437 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.908401 W
# *** Time step 439: t = 438 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.908807 W
# *** Time step 440: t = 439 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.909208 W
# *** Time step 441: t = 440 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.909601 W
# *** Time step 442: t = 441 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.909996 W
# *** Time step 443: t = 442 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.910382 W
# *** Time step 444: t = 443 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.910765 W
# *** Time step 445: t = 444 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.91114 W
# *** Time step 446: t = 445 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.911513 W
# *** Time step 447: t = 446 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.911878 W
# *** Time step 448: t = 447 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.912237 W
# *** Time step 449: t = 448 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.912601 W
# *** Time step 450: t = 449 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.91296 W
# *** Time step 451: t = 450 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.913305 W
# *** Time step 452: t = 451 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.913662 W
# *** Time step 453: t = 452 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.914009 W
# *** Time step 454: t = 453 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.91435 W
# *** Time step 455: t = 454 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.914687 W
# *** Time step 456: t = 455 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.915043 W
# *** Time step 457: t = 456 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.915374 W
# *** Time step 458: t = 457 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.915707 W
# *** Time step 459: t = 458 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.916043 W
# *** Time step 460: t = 459 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.916346 W
# *** Time step 461: t = 460 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.916674 W
# *** Time step 462: t = 461 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.9169 W
# *** Time step 463: t = 462 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.917239 W
# *** Time step 464: t = 463 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.917574 W
# *** Time step 465: t = 464 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.917906 W
# *** Time step 466: t = 465 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.918236 W
# *** Time step 467: t = 466 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.918563 W
# *** Time step 468: t = 467 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.918883 W
# *** Time step 469: t = 468 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.91919 W
# *** Time step 470: t = 469 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.919494 W
# *** Time step 471: t = 470 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.919788 W
# *** Time step 472: t = 471 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.920075 W
# *** Time step 473: t = 472 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.920357 W
# *** Time step 474: t = 473 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92062 W
# *** Time step 475: t = 474 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.920884 W
# *** Time step 476: t = 475 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.921157 W
# *** Time step 477: t = 476 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.921432 W
# *** Time step 478: t = 477 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.921702 W
# *** Time step 479: t = 478 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.921966 W
# *** Time step 480: t = 479 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.922228 W
# *** Time step 481: t = 480 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.922481 W
# *** Time step 482: t = 481 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.922734 W
# *** Time step 483: t = 482 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92299 W
# *** Time step 484: t = 483 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.923235 W
# *** Time step 485: t = 484 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.923486 W
# *** Time step 486: t = 485 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.923728 W
# *** Time step 487: t = 486 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.923967 W
# *** Time step 488: t = 487 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.924206 W
# *** Time step 489: t = 488 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.924439 W
# *** Time step 490: t = 489 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.924671 W
# *** Time step 491: t = 490 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.924896 W
# *** Time step 492: t = 491 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.925122 W
# *** Time step 493: t = 492 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92534 W
# *** Time step 494: t = 493 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.925556 W
# *** Time step 495: t = 494 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92576 W
# *** Time step 496: t = 495 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.925962 W
# *** Time step 497: t = 496 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92616 W
# *** Time step 498: t = 497 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92637 W
# *** Time step 499: t = 498 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.926572 W
# *** Time step 500: t = 499 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92677 W
# *** Time step 501: t = 500 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.926968 W
# *** Time step 502: t = 501 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.927161 W
# *** Time step 503: t = 502 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.927348 W
# *** Time step 504: t = 503 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.927533 W
# *** Time step 505: t = 504 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92766 W
# *** Time step 506: t = 505 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.92784 W
# *** Time step 507: t = 506 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928023 W
# *** Time step 508: t = 507 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928201 W
# *** Time step 509: t = 508 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928376 W
# *** Time step 510: t = 509 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928548 W
# *** Time step 511: t = 510 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928716 W
# *** Time step 512: t = 511 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.928882 W
# *** Time step 513: t = 512 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929045 W
# *** Time step 514: t = 513 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929207 W
# *** Time step 515: t = 514 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929369 W
# *** Time step 516: t = 515 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929519 W
# *** Time step 517: t = 516 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929667 W
# *** Time step 518: t = 517 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929812 W
# *** Time step 519: t = 518 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.929954 W
# *** Time step 520: t = 519 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930093 W
# *** Time step 521: t = 520 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930229 W
# *** Time step 522: t = 521 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930361 W
# *** Time step 523: t = 522 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930491 W
# *** Time step 524: t = 523 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930619 W
# *** Time step 525: t = 524 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930743 W
# *** Time step 526: t = 525 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930865 W
# *** Time step 527: t = 526 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.930984 W
# *** Time step 528: t = 527 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.931099 W
# *** Time step 529: t = 528 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.931211 W
# *** Time step 530: t = 529 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 0.931323 W
# *** Time step 531: t = 530 s ***
# ...
# *** Time step 1027: t = 1026 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.28057 W
# *** Time step 1028: t = 1027 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.28313 W
# *** Time step 1029: t = 1028 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.28569 W
# *** Time step 1030: t = 1029 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.28824 W
# *** Time step 1031: t = 1030 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.29082 W
# *** Time step 1032: t = 1031 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.2934 W
# *** Time step 1033: t = 1032 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.29601 W
# *** Time step 1034: t = 1033 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.29862 W
# *** Time step 1035: t = 1034 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.30123 W
# *** Time step 1036: t = 1035 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.30387 W
# *** Time step 1037: t = 1036 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.3065 W
# *** Time step 1038: t = 1037 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.30915 W
# *** Time step 1039: t = 1038 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.31181 W
# *** Time step 1040: t = 1039 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.31448 W
# *** Time step 1041: t = 1040 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.31715 W
# *** Time step 1042: t = 1041 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.31985 W
# *** Time step 1043: t = 1042 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.32255 W
# *** Time step 1044: t = 1043 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.32526 W
# *** Time step 1045: t = 1044 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.32798 W
# *** Time step 1046: t = 1045 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.3307 W
# *** Time step 1047: t = 1046 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.33345 W
# *** Time step 1048: t = 1047 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.3362 W
# *** Time step 1049: t = 1048 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.33896 W
# *** Time step 1050: t = 1049 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.34173 W
# *** Time step 1051: t = 1050 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.3445 W
# *** Time step 1052: t = 1051 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.34729 W
# *** Time step 1053: t = 1052 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.35009 W
# *** Time step 1054: t = 1053 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.35291 W
# *** Time step 1055: t = 1054 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.35573 W
# *** Time step 1056: t = 1055 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.35856 W
# *** Time step 1057: t = 1056 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.36139 W
# *** Time step 1058: t = 1057 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.36425 W
# *** Time step 1059: t = 1058 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.3671 W
# *** Time step 1060: t = 1059 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.36997 W
# *** Time step 1061: t = 1060 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.37285 W
# *** Time step 1062: t = 1061 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.37573 W
# *** Time step 1063: t = 1062 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.37863 W
# *** Time step 1064: t = 1063 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.38154 W
# *** Time step 1065: t = 1064 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.38446 W
# *** Time step 1066: t = 1065 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.38738 W
# *** Time step 1067: t = 1066 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.39031 W
# *** Time step 1068: t = 1067 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.39325 W
# *** Time step 1069: t = 1068 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.39621 W
# *** Time step 1070: t = 1069 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.39917 W
# *** Time step 1071: t = 1070 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.40214 W
# *** Time step 1072: t = 1071 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.40513 W
# *** Time step 1073: t = 1072 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.4081 W
# *** Time step 1074: t = 1073 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.4111 W
# *** Time step 1075: t = 1074 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.41411 W
# *** Time step 1076: t = 1075 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.41714 W
# *** Time step 1077: t = 1076 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.42016 W
# *** Time step 1078: t = 1077 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.42319 W
# *** Time step 1079: t = 1078 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.42625 W
# *** Time step 1080: t = 1079 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.42929 W
# *** Time step 1081: t = 1080 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.43235 W
# *** Time step 1082: t = 1081 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.43543 W
# *** Time step 1083: t = 1082 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.43851 W
# *** Time step 1084: t = 1083 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.4416 W
# *** Time step 1085: t = 1084 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.44469 W
# *** Time step 1086: t = 1085 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.44782 W
# *** Time step 1087: t = 1086 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.45091 W
# *** Time step 1088: t = 1087 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.45404 W
# *** Time step 1089: t = 1088 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.45719 W
# *** Time step 1090: t = 1089 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.46031 W
# *** Time step 1091: t = 1090 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.46347 W
# *** Time step 1092: t = 1091 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.46662 W
# *** Time step 1093: t = 1092 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.46981 W
# *** Time step 1094: t = 1093 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.47297 W
# *** Time step 1095: t = 1094 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.47615 W
# *** Time step 1096: t = 1095 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.47933 W
# *** Time step 1097: t = 1096 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.48255 W
# *** Time step 1098: t = 1097 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.48575 W
# *** Time step 1099: t = 1098 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.48896 W
# *** Time step 1100: t = 1099 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.49218 W
# *** Time step 1101: t = 1100 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.49542 W
# *** Time step 1102: t = 1101 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.49865 W
# *** Time step 1103: t = 1102 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.50191 W
# *** Time step 1104: t = 1103 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.50515 W
# *** Time step 1105: t = 1104 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.50841 W
# *** Time step 1106: t = 1105 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.51169 W
# *** Time step 1107: t = 1106 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.51497 W
# *** Time step 1108: t = 1107 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.51827 W
# *** Time step 1109: t = 1108 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.52154 W
# *** Time step 1110: t = 1109 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.52484 W
# *** Time step 1111: t = 1110 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.52816 W
# *** Time step 1112: t = 1111 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.53147 W
# *** Time step 1113: t = 1112 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.53479 W
# *** Time step 1114: t = 1113 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.53812 W
# *** Time step 1115: t = 1114 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.54146 W
# *** Time step 1116: t = 1115 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.5448 W
# *** Time step 1117: t = 1116 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.54815 W
# *** Time step 1118: t = 1117 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.5515 W
# *** Time step 1119: t = 1118 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.55486 W
# *** Time step 1120: t = 1119 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.55823 W
# *** Time step 1121: t = 1120 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.56163 W
# *** Time step 1122: t = 1121 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.56501 W
# *** Time step 1123: t = 1122 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.5684 W
# *** Time step 1124: t = 1123 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.5718 W
# *** Time step 1125: t = 1124 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.57521 W
# *** Time step 1126: t = 1125 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.57864 W
# *** Time step 1127: t = 1126 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.58203 W
# *** Time step 1128: t = 1127 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.58545 W
# *** Time step 1129: t = 1128 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.58888 W
# *** Time step 1130: t = 1129 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.59232 W
# *** Time step 1131: t = 1130 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.59576 W
# *** Time step 1132: t = 1131 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.59922 W
# *** Time step 1133: t = 1132 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.60266 W
# *** Time step 1134: t = 1133 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.60613 W
# *** Time step 1135: t = 1134 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.60959 W
# *** Time step 1136: t = 1135 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.61306 W
# *** Time step 1137: t = 1136 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.61655 W
# *** Time step 1138: t = 1137 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.62003 W
# *** Time step 1139: t = 1138 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.62352 W
# *** Time step 1140: t = 1139 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.62702 W
# *** Time step 1141: t = 1140 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.63051 W
# *** Time step 1142: t = 1141 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.63402 W
# *** Time step 1143: t = 1142 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.63753 W
# *** Time step 1144: t = 1143 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.64105 W
# *** Time step 1145: t = 1144 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.64456 W
# *** Time step 1146: t = 1145 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.64809 W
# *** Time step 1147: t = 1146 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.65162 W
# *** Time step 1148: t = 1147 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.65516 W
# *** Time step 1149: t = 1148 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.65869 W
# *** Time step 1150: t = 1149 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.66224 W
# *** Time step 1151: t = 1150 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.6658 W
# *** Time step 1152: t = 1151 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.66935 W
# *** Time step 1153: t = 1152 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.67291 W
# *** Time step 1154: t = 1153 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.67647 W
# *** Time step 1155: t = 1154 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.68004 W
# *** Time step 1156: t = 1155 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.68361 W
# *** Time step 1157: t = 1156 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.68718 W
# *** Time step 1158: t = 1157 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.69077 W
# *** Time step 1159: t = 1158 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.69435 W
# *** Time step 1160: t = 1159 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.69793 W
# *** Time step 1161: t = 1160 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.70153 W
# *** Time step 1162: t = 1161 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.70511 W
# *** Time step 1163: t = 1162 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.70872 W
# *** Time step 1164: t = 1163 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.71231 W
# *** Time step 1165: t = 1164 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.71593 W
# *** Time step 1166: t = 1165 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.71952 W
# *** Time step 1167: t = 1166 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.72313 W
# *** Time step 1168: t = 1167 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.72676 W
# *** Time step 1169: t = 1168 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.73038 W
# *** Time step 1170: t = 1169 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.73399 W
# *** Time step 1171: t = 1170 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.73763 W
# *** Time step 1172: t = 1171 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.74124 W
# *** Time step 1173: t = 1172 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.74487 W
# *** Time step 1174: t = 1173 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.7485 W
# *** Time step 1175: t = 1174 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.75213 W
# *** Time step 1176: t = 1175 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.75576 W
# *** Time step 1177: t = 1176 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.75941 W
# *** Time step 1178: t = 1177 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.76305 W
# *** Time step 1179: t = 1178 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.76669 W
# *** Time step 1180: t = 1179 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.77034 W
# *** Time step 1181: t = 1180 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.77398 W
# *** Time step 1182: t = 1181 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.77763 W
# *** Time step 1183: t = 1182 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.78128 W
# *** Time step 1184: t = 1183 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.78492 W
# *** Time step 1185: t = 1184 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.78856 W
# *** Time step 1186: t = 1185 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.79221 W
# *** Time step 1187: t = 1186 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.79587 W
# *** Time step 1188: t = 1187 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.79953 W
# *** Time step 1189: t = 1188 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.80319 W
# *** Time step 1190: t = 1189 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.80684 W
# *** Time step 1191: t = 1190 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.8105 W
# *** Time step 1192: t = 1191 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.81416 W
# *** Time step 1193: t = 1192 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.81781 W
# *** Time step 1194: t = 1193 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.82147 W
# *** Time step 1195: t = 1194 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.82514 W
# *** Time step 1196: t = 1195 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.82879 W
# *** Time step 1197: t = 1196 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.83245 W
# *** Time step 1198: t = 1197 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.8361 W
# *** Time step 1199: t = 1198 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.83978 W
# *** Time step 1200: t = 1199 s ***
# Minimum heat transfer segment: 10, Q_cool_HT = 1.84342 W

# %%
# save T_bat_history into a single excel file for further analysis

import pandas

file_name = os.path.join(PROJECT_ROOT, 'data', CASE_ID, f"{CASE_NAME}.xlsx" )

# create the output folder if it does not exist
output_dir = os.path.dirname(file_name)
os.makedirs(output_dir, exist_ok=True)  
num_seg = N_cells

T_bat_df = pd.DataFrame(T_bat_history.tolist(), columns = [f"T_Segment_{i+1}" for i in range(num_seg)])

for i in range(N_cool_seg):
    T_bat_df[f"T_cool_{i+1}"] = [T_cool_history[j][i] for j in range(num_time_steps)]


T_bat_df.to_excel(file_name, sheet_name="T_bat_history", index=False) # let sheet name = "T_bat_history"

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

time_s = np.arange(num_time_steps) * dt

Tmax_1D = np.array([max(T_bat_history[i]) for i in range(num_time_steps)])  # 取每个时间步最后一个电池单元的温度作为 max
T9_1D = np.array([T_bat_history[i][9] for i in range(num_time_steps)])

Tmin_1D = np.array([T_bat_history[i][5] for i in range(num_time_steps)]) # Liu told me that the 10th battery cell typically has the minimum temperature
# Tmin_1D = np.array([min(T_bat_history[i]) for i in range(num_time_steps)])   # 取每个时间步第一个电池单元的温度作为 min

plt.plot(time_s, Tmax_1D, linestyle="--", label="1D-max")
plt.plot(time_s, Tmin_1D, linestyle="--", label="1D-min")
plt.plot(time_s, T9_1D, linestyle="--", label="1D-9")

# 绘制所有已成功读取的 CFD 数据，包括新增的 CFD_min_avg / CFD_max_avg。
for label, data in cfd_series:
    plt.plot(data["time_s"], data["temperature"], label=label)    

plt.plot(BLC_max[:, 0], BLC_max[:, 1]-273.15, linestyle='-.', label="Zhang, BLC-max")
plt.plot(BLC_min[:, 0], BLC_min[:, 1]-273.15, linestyle='-.', label="Zhang, BLC-min")

# plot battery temperature without cooling for reference
# plt.plot(time_s, T_bat_wo_cooling, linestyle=":", label="1D-wo-cooling")

# plot the battery temperature calculated from the 0D model for reference
plt.plot(time_s[:-1], T_bat_history_0D[:-1], linestyle=":", label="0D")
plt.plot(time_s[:-1], T_cool_history_0D[:-1], linestyle=":", label="0D-cool, out")

# set the range of the y-axis for temperature comparison
# plt.ylim(23, 60)

plt.xlabel("Simulation time (s)")
plt.ylabel("Temperature (K)")
plt.title("Liquid Cooling / CFD / BLC Temperature Comparison")
plt.grid(True)
plt.legend()
plt.tight_layout()

# plot_path = os.path.join(output_dir, "plot_liquid_cfd_avg_comparison.png")
# plt.savefig(plot_path, dpi=600)
plt.show()

# print(f"Saved comparison plot to: {plot_path}")
if cfd_series:
    print("Loaded CFD series:", ", ".join([f"{label} rows={len(data)}" for label, data in cfd_series]))
else:
    print("WARNING: no CFD .out files were loaded. Please check CFD_DATA_DIR and CFD_SERIES_FILES.")
# Out:
# Loaded CFD series: CFD_max rows=1201, CFD_min rows=1201, CFD_max_avg rows=1201, CFD_min_avg rows=1201
